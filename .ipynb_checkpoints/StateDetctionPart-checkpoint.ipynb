# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
all_files = glob.glob("Training/*/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    state_type = 3
    if 'Spontan' in filename:
        state_type = 1
    elif 'Sync' in filename:
        state_type = 2
    df['state_type'] = state_type
    df['name'] = filename.split("\\")[1]
    li.append(df)

li.append(pd.read_csv("HandRight.csv",index_col=None, header=0))
df = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# # Labels
#
#
# | Label | Description |
# | --- | --- |
# | 1 | Spontan |
# | 2 | Sync |
# | 3 | Alone |

# %%
df.sample(20)
# Out:
#              Time   Frame ID  Hand Type   # hands   Position X   Position Y  \
# 126536  614.73080      70925      right         1  -199.182300     262.1404
# 327019  757.92920      59389       left         1  -140.085900     237.4290
# 188047  312.60260      36753       left         2   -93.545590     145.4675
# 257262  398.75070      46346      right         1    -6.049986     285.5152
# 65002   338.70030      40048       left         2  -235.800000     168.1934
# 142387  132.49290      15879       left         2  -114.859400     185.6567
# 254189  310.46310      36168       left         1    51.086950     255.3476
# 296084  249.57790      29303      right         2   168.316600     218.0446
# 3948     97.10896     101032       left         2  -126.169700     260.9012
# 335000  182.60290      21741      right         1    -4.421564     225.8964
# 261363  434.96580      50521      right         2   149.625300     329.5399
# ...

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)
list(df)
# Out:
# ['Time',
#  'Frame ID',
#  'Hand Type',
#  '# hands',
#  'Position X',
#  'Position Y',
#  'Position Z',
#  'Velocity X',
#  'Velocity Y',
#  'Velocity Z',
#  'Pitch',
#  'Roll',
#  'Yaw',
#  'Wrist Pos X',
#  'Wrist Pos Y',
#  'Wrist Pos Z',
#  'Elbow pos X',
#  'Elbow Pos Y',
#  'Elbow Pos Z',
#  'Grab Strenth',
#  'Grab Angle',
#  'Pinch Strength',
#  'state_type',
#  'name']

# %%
df = df.sort_values('Frame ID')
df['Frame ID'].value_counts()
# Out:
# 48864     14
# 48736     14
# 47905     13
# 47977     13
# 48384     13
#           ..
# 54867      1
# 123130     1
# 125179     1
# 156879     1
# 154644     1
# Name: Frame ID, Length: 101794, dtype: int64

# %%
from mpl_toolkits.mplot3d import Axes3D 

person = df.name.unique()[0]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.loc[df["name"]==person,"Position X"].values, df.loc[df["name"]==person,"Position Y"].values, df.loc[df["name"]==person,"Position Z"].values,marker="o")

plt.show()
