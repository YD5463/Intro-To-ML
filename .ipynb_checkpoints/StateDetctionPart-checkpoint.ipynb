# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
def construct_datasets(path_type):
    all_files = glob.glob(path_type)
    li = []

    for filename in all_files:
        df = pd.read_csv(filename, index_col=None, header=0)
        df.rename(columns=lambda x: x.strip(), inplace=True)
        state_type = 3
        if 'Spontan' in filename:
            state_type = 1
        elif 'Sync' in filename:
            state_type = 2
        df['state_type'] = state_type
        df['name'] = filename.split("\\")[1]
        li.append(df)
    
    df = pd.concat(li, axis=0, ignore_index=True)
    alone_right = pd.read_csv("HandRight.csv",index_col=None, header=0)
    alone_right.rename(columns=lambda x: x.strip(), inplace=True)
    alone_right["state_type"] = 3
    alone_right["name"] = ""
    df = alone_right.merge(df, how='right')
    
    return df
df = construct_datasets("Training/*/*.csv")

# %% [markdown]
# # Labels
#
#
# | Label | Description |
# | --- | --- |
# | 1 | Spontan |
# | 2 | Sync |
# | 3 | Alone |

# %%
df = df.sort_values('Frame ID')
df['Frame ID'].value_counts()
# Out:
# 48864     14
# 48736     14
# 47905     13
# 49291     13
# 48044     13
#           ..
# 153093     1
# 69179      1
# 70750      1
# 73273      1
# 121275     1
# Name: Frame ID, Length: 101503, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331720 entries, 90445 to 45215
# Data columns (total 24 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Time            331720 non-null  float64
#  1   Frame ID        331720 non-null  int64
#  2   Hand Type       331720 non-null  object
#  3   # hands         331720 non-null  int64
#  4   Position X      331720 non-null  float64
#  5   Position Y      331720 non-null  float64
#  6   Position Z      331720 non-null  float64
#  7   Velocity X      331720 non-null  float64
#  8   Velocity Y      331720 non-null  float64
#  9   Velocity Z      331720 non-null  float64
#  10  Pitch           331720 non-null  float64
#  11  Roll            331720 non-null  float64
#  12  Yaw             331720 non-null  float64
#  13  Wrist Pos X     331720 non-null  float64
#  14  Wrist Pos Y     331720 non-null  float64
#  15  Wrist Pos Z     331720 non-null  float64
#  16  Elbow pos X     331720 non-null  float64
#  17  Elbow Pos Y     331720 non-null  float64
#  18  Elbow Pos Z     331720 non-null  float64
#  19  Grab Strenth    331720 non-null  float64
#  20  Grab Angle      331720 non-null  float64
#  21  Pinch Strength  331720 non-null  float64
#  22  state_type      331720 non-null  int64
#  23  name            331720 non-null  object
# dtypes: float64(19), int64(3), object(2)
# memory usage: 63.3+ MB

# %%
df
# Out:
#             Time  Frame ID Hand Type  # hands  Position X  Position Y  \
# 90445   52.00663      6065      left        2  -264.11730    224.1980
# 90446   52.00663      6065     right        2   143.96350    273.1676
# 90447   52.02296      6067      left        2  -262.93600    223.0686
# 90448   52.02296      6067     right        2   146.61040    276.7957
# 90449   52.03953      6069      left        2  -262.71840    222.9204
# ...          ...       ...       ...      ...         ...         ...
# 45211  593.71770    158254      left        1   -44.79453    123.7657
# 45212  593.73430    158256      left        1   -40.77390    126.7342
# 45213  593.75090    158257      left        1   -38.56184    127.6858
# 45214  593.76810    158259      left        1   -35.88303    132.9386
# 45215  593.78400    158261      left        1   -33.63328    139.4063
#
#        Position Z  Velocity X  Velocity Y  Velocity Z  ...  Wrist Pos Y  \
# 90445   75.899460   158.97420  -96.678280   -95.49094  ...     157.6220
# 90446  103.945900   141.35620  225.921900   563.77390  ...     225.3446
# 90447   74.124690    47.73351  -59.637230  -104.94280  ...     156.1815
# 90448  113.326100   140.84840  226.428100   526.52500  ...     228.3056
# 90449   72.608060    11.94497    7.158736   -78.16367  ...     155.6225
# ...           ...         ...         ...         ...  ...          ...
# 45211   -6.241947   274.44630  106.789200   125.05260  ...     107.5486
# 45212   -3.452266   223.52940  209.723900   160.24900  ...     110.7256
# 45213   -2.086977   254.93310  109.661300   157.34590  ...     111.9989
# 45214    0.526575   185.86870  204.982200   154.04880  ...     116.3043
# 45215    2.912675   119.74400  382.613500   141.81010  ...     120.6218
#
#        Wrist Pos Z  Elbow pos X  Elbow Pos Y  Elbow Pos Z  Grab Strenth  \
# 90445    52.981640    -393.1893    -69.68469     74.90703           0.0
# 90446   112.823900     371.4650     41.49383    154.26700           0.0
# 90447    51.688190    -376.5264    -78.07376     75.58520           0.0
# 90448   119.555800     364.9230     36.24656    160.07720           0.0
# 90449    50.634270    -355.8537    -85.19637     81.18176           0.0
# ...            ...          ...          ...          ...           ...
# 45211    -6.354107    -354.6525     41.16571     45.73993           0.0
# 45212    -3.791958    -351.3217     53.68426     55.64309           0.0
# 45213    -2.676469    -349.8930     59.75835     58.19042           0.0
# 45214     0.041351    -346.9033     66.47016     63.19174           0.0
# 45215     2.738251    -343.8961     69.92101     66.05376           0.0
#
#        Grab Angle  Pinch Strength  state_type                name
# 90445    0.000000             0.0           1  Oriya Social_Nuero
# 90446    0.749941             0.0           1  Oriya Social_Nuero
# 90447    0.010044             0.0           1  Oriya Social_Nuero
# 90448    0.926566             0.0           1  Oriya Social_Nuero
# 90449    0.069474             0.0           1  Oriya Social_Nuero
# ...           ...             ...         ...                 ...
# 45211    0.401728             0.0           3       Evyatar Cohen
# 45212    0.190267             0.0           3       Evyatar Cohen
# 45213    0.042665             0.0           3       Evyatar Cohen
# 45214    0.000000             0.0           3       Evyatar Cohen
# 45215    0.000000             0.0           3       Evyatar Cohen
#
# [331720 rows x 24 columns]

# %%
import matplotlib.dates as matdates

def plot_position_over_time(position):
    print(position,"over time")
    for name in df["name"].dropna().unique()[:1]:#you can remove the [] to print for all persons
        print("plot position of",name)
        fig, ax = plt.subplots(nrows=3, ncols=3,figsize=(20,10))
        for state_type in range(1,4):
            x_pos_over_timer = df[(df["name"]==name) & (df["state_type"]==state_type)][["Time",position,"Hand Type"]]
            left_x_pos_over_timer = x_pos_over_timer[x_pos_over_timer["Hand Type"]=="left"]
            right_x_pos_over_timer = x_pos_over_timer[x_pos_over_timer["Hand Type"]=="right"]
            ax[state_type-1][0].plot(left_x_pos_over_timer["Time"],left_x_pos_over_timer[position])
            ax[state_type-1][0].plot(right_x_pos_over_timer["Time"],right_x_pos_over_timer[position])
            ax[state_type-1][1].plot(left_x_pos_over_timer["Time"],left_x_pos_over_timer[position])
            ax[state_type-1][2].plot(right_x_pos_over_timer["Time"],right_x_pos_over_timer[position],"m")
        plt.show()
plot_position_over_time("Position X")
# Out:
# Position X over time
# plot position of Oriya Social_Nuero

# %%
plot_position_over_time("Position Y")
# Out:
# Position Y over time
# plot position of Oriya Social_Nuero

# %%
plot_position_over_time("Position Z")
# Out:
# Position Z over time
# plot position of Oriya Social_Nuero

# %% [markdown]
# # Models

# %%
import xgboost as xgb
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.svm import SVC
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.decomposition import PCA
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
import warnings
#warnings.filterwarnings('ignore')

# %%
y = df["state_type"]
X = df.drop(['Frame ID','Hand Type','# hands','name','state_type'], axis=1)
kf = KFold(n_splits=4,shuffle=True,random_state=93)

# %%
rnd_clf = RandomForestClassifier(n_estimators=100,max_depth=100)
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    print(y_test)
    print("\n\n\n")
    rnd_clf = rnd_clf.fit(X_train,y_train)
    y_pred = rnd_clf.predict(X_test)
    print(classification_report(y_test, y_pred))
# Out:
#             Time  Position X  Position Y  Position Z  Velocity X  Velocity Y  \
# 90445   52.00663  -264.11730    224.1980   75.899460   158.97420  -96.678280
# 90446   52.00663   143.96350    273.1676  103.945900   141.35620  225.921900
# 90447   52.02296  -262.93600    223.0686   74.124690    47.73351  -59.637230
# 90448   52.02296   146.61040    276.7957  113.326100   140.84840  226.428100
# 90449   52.03953  -262.71840    222.9204   72.608060    11.94497    7.158736
# ...          ...         ...         ...         ...         ...         ...
# 45205  593.61830   -74.42316    120.6154  -10.760580   252.93860  -27.014550
# 45208  593.66810   -59.38176    119.3733  -10.664750   290.60730   14.524610
# 45210  593.70110   -49.57425    122.1104   -8.427519   294.34860   18.713210
# 45211  593.71770   -44.79453    123.7657   -6.241947   274.44630  106.789200
# 45214  593.76810   -35.88303    132.9386    0.526575   185.86870  204.982200
#
#        Velocity Z     Pitch      Roll       Yaw  Wrist Pos X  Wrist Pos Y  \
# 90445   -95.49094  1.830654  1.312434  2.697659    -276.4461     157.6220
# 90446   563.77390  1.232105 -0.794526 -1.242502     197.5127     225.3446
# 90447  -104.94280  1.824006  1.321716  2.683746    -274.8828     156.1815
# 90448   526.52500  1.285719 -0.797713 -1.296234     199.8491     228.3056
# 90449   -78.16367  1.820370  1.340818  2.727431    -273.0819     155.6225
# ...           ...       ...       ...       ...          ...          ...
# 45205   -12.68219  0.832581  0.255372  1.382804    -144.9039     107.6729
# 45208    52.49761  1.123607  0.300491  1.435401    -128.9904     102.1399
# 45210   117.22530  1.217994  0.285451  1.469654    -119.2967     105.5841
# 45211   125.05260  1.234747  0.282478  1.476095    -114.5244     107.5486
# 45214   154.04880  1.299061  0.298048  1.489702    -105.4344     116.3043
#
#        Wrist Pos Z  Elbow pos X  Elbow Pos Y  Elbow Pos Z  Grab Strenth  \
# 90445    52.981640    -393.1893    -69.68469     74.90703      0.000000
# 90446   112.823900     371.4650     41.49383    154.26700      0.000000
# 90447    51.688190    -376.5264    -78.07376     75.58520      0.000000
# 90448   119.555800     364.9230     36.24656    160.07720      0.000000
# 90449    50.634270    -355.8537    -85.19637     81.18176      0.000000
# ...            ...          ...          ...          ...           ...
# 45205    -6.264637    -390.6847     48.43399     23.07514      0.042081
# 45208    -9.114032    -369.7166     26.68345     24.58289      0.000000
# 45210    -8.572108    -359.9635     33.54824     32.27609      0.000000
# 45211    -6.354107    -354.6525     41.16571     45.73993      0.000000
# 45214     0.041351    -346.9033     66.47016     63.19174      0.000000
#
#        Grab Angle  Pinch Strength
# 90445    0.000000             0.0
# 90446    0.749941             0.0
# 90447    0.010044             0.0
# 90448    0.926566             0.0
# 90449    0.069474             0.0
# ...           ...             ...
# 45205    1.167262             0.0
# 45208    0.834168             0.0
# 45210    0.375408             0.0
# 45211    0.401728             0.0
# 45214    0.000000             0.0
#
# [165860 rows x 19 columns]
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 331709    2
# 331712    2
# 331714    2
# 331715    2
# 331718    2
# Name: state_type, Length: 165860, dtype: int64
#
#
#
#
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99     67011
#            2       0.99      0.99      0.99     67081
#            3       1.00      0.97      0.98     31768
#
#     accuracy                           0.99    165860
#    macro avg       0.99      0.99      0.99    165860
# weighted avg       0.99      0.99      0.99    165860
#
#             Time  Position X  Position Y  Position Z  Velocity X  Velocity Y  \
# 90450   52.03953   151.57950    281.5556  122.646600   313.37950   245.60920
# 90451   52.05610  -260.45000    222.7352   71.137710   166.10680   -24.06143
# 90453   52.07340  -256.45730    220.3226   68.916520   230.05660  -150.79120
# 90455   52.08935  -256.05510    219.2970   67.018910   -44.50033   -26.17178
# 90459   52.12236  -256.76600    219.3221   64.759070    15.08481    28.91949
# ...          ...         ...         ...         ...         ...         ...
# 45207  593.65170   -64.67839    120.0930  -11.560220   318.24280   -86.83499
# 45209  593.68510   -54.63017    120.7100   -9.798771   257.11010   106.09850
# 45212  593.73430   -40.77390    126.7342   -3.452266   223.52940   209.72390
# 45213  593.75090   -38.56184    127.6858   -2.086977   254.93310   109.66130
# 45215  593.78400   -33.63328    139.4063    2.912675   119.74400   382.61350
#
#        Velocity Z     Pitch      Roll       Yaw  Wrist Pos X  Wrist Pos Y  \
# 90450   531.19300  1.352377 -0.801721 -1.356994     204.2975     232.2564
# 90451   -89.72137  1.817664  1.345590  2.750283    -270.1986     155.2931
# 90453  -127.22610  1.809205  1.344689  2.743306    -266.2641     152.7508
# 90455  -104.60110  1.798305  1.372303  2.798993    -264.6962     151.3495
# 90459   -72.39090  1.798166  1.387068  2.861388    -263.7653     151.1346
# ...           ...       ...       ...       ...          ...          ...
# 45207    11.94818  1.060400  0.312756  1.409603    -134.2111     102.5542
# 45209    49.73554  1.177975  0.281346  1.458587    -124.4335     104.4134
# 45212   160.24900  1.265178  0.283400  1.484591    -110.5008     110.7256
# 45213   157.34590  1.279585  0.280169  1.489703    -108.3443     111.9989
# 45215   141.81010  1.315801  0.334827  1.484309    -102.6475     120.6218
#
#        Wrist Pos Z  Elbow pos X  Elbow Pos Y  Elbow Pos Z  Grab Strenth  \
# 90450   125.736800     364.7589     35.26894    160.75300      0.016851
# 90451    49.440150    -351.8264    -85.45685     83.41654      0.000000
# 90453    47.684160    -355.6522    -85.27079     81.35184      0.000000
# 90455    46.457130    -350.7600    -87.68739     81.56274      0.000000
# 90459    44.514150    -333.1446    -91.99749     87.54149      0.000000
# ...            ...          ...          ...          ...           ...
# 45207    -8.612695    -376.2469     30.43111     22.93399      0.000000
# 45209    -9.395606    -364.7231     28.79553     26.95136      0.000000
# 45212    -3.791958    -351.3217     53.68426     55.64309      0.000000
# 45213    -2.676469    -349.8930     59.75835     58.19042      0.000000
# 45215     2.738251    -343.8961     69.92101     66.05376      0.000000
#
#        Grab Angle  Pinch Strength
# 90450    1.125768             0.0
# 90451    0.049737             0.0
# 90453    0.035254             0.0
# 90455    0.057224             0.0
# 90459    0.093299             0.0
# ...           ...             ...
# 45207    0.845156             0.0
# 45209    0.775767             0.0
# 45212    0.190267             0.0
# 45213    0.042665             0.0
# 45215    0.000000             0.0
#
# [165860 rows x 19 columns]
# 5         1
# 6         1
# 8         1
# 10        1
# 14        1
#          ..
# 331711    2
# 331713    2
# 331716    2
# 331717    2
# 331719    2
# Name: state_type, Length: 165860, dtype: int64

# %%
param_list = [("eta", 0.08), ("max_depth", 6), ("subsample", 0.8), ("colsample_bytree", 0.8), ("objective", "multi:softmax"), ("eval_metric", "merror"), ("alpha", 8), ("lambda", 2), ("num_class", 10)]
n_rounds = 600
early_stopping = 50

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    d_train = xgb.DMatrix(X_train, label=y_train)
    d_val = xgb.DMatrix(X_test, label=y_test)
    eval_list = [(d_train, "train"), (d_val, "validation")]
    bst = xgb.train(param_list, d_train, n_rounds, evals=eval_list, early_stopping_rounds=early_stopping, verbose_eval=True)

# %%
d_test = xgb.DMatrix(data=testX)
y_pred = bst.predict(d_test)
print(classification_report(testY, y_pred))

# %% [markdown]
# # Validation

# %%
test_df = construct_datasets("Validation/*/*.csv")
# Out:
#            Time  Frame ID Hand Type  # hands  Position X  Position Y  \
# 0      445.3185     52654     right        2   128.15300    218.7197
# 1      445.3185     52654      left        2  -118.79860    189.2057
# 2      445.3350     52656     right        2   128.68630    217.6665
# 3      445.3350     52656      left        2  -118.34750    188.5808
# 4      445.3514     52658     right        2   129.78710    217.3515
# ...         ...       ...       ...      ...         ...         ...
# 90008  998.8158     66221      left        2   -96.74767    323.8981
# 90009  998.8495     66224     right        2   111.83100    324.5124
# 90010  998.8495     66224      left        2   -95.67720    329.8123
# 90011  998.8855     66227     right        2   113.80260    325.5213
# 90012  998.8855     66227      left        2   -94.29232    334.7815
#
#        Position Z  Velocity X  Velocity Y  Velocity Z  ...  Wrist Pos Y  \
# 0        60.37725    47.95857   -39.96753  -52.944150  ...     199.7000
# 1        22.02865    18.57612   -24.75736   -6.268249  ...     166.5372
# 2        59.12631    45.23807   -41.40622  -67.647170  ...     198.8316
# 3        22.01872    25.97076   -32.45813    0.125023  ...     166.5907
# 4        57.75356    66.80715   -13.31386  -93.414820  ...     199.9675
# ...           ...         ...         ...         ...  ...          ...
# 90008    76.98316    27.14988   185.62180   33.741870  ...     267.8716
# 90009   102.83410    86.42312   119.68330  -13.673710  ...     269.7217
# 90010    78.13316    47.37696   118.31670   24.152470  ...     273.4537
# 90011   101.48600    54.98372    11.75017  -37.260060  ...     270.7919
# 90012    78.81863    31.57111   132.41000   13.034000  ...     278.6703
#
#        Wrist Pos Z  Elbow pos X  Elbow Pos Y  Elbow Pos Z  Grab Strenth  \
# 0         68.58939     370.8766     35.98276     114.1168           0.0
# 1         39.80411    -389.7113    102.57890     153.5285           0.0
# 2         65.92238     380.3675     45.75144     114.1267           0.0
# 3         39.26244    -391.7210     99.02240     147.0519           0.0
# 4         63.32793     391.6194     59.67964     112.6302           0.0
# ...            ...          ...          ...          ...           ...
# 90008     68.90888    -298.0420     57.52314     124.0967           0.0
# 90009    103.07490     340.7914     72.96347     121.5707           0.0
# 90010     69.90453    -300.8497     65.10999     120.6967           0.0
# 90011    101.25900     344.8011     75.97822     121.1411           0.0
# 90012     70.61062    -304.8143     74.33545     121.8350           0.0
#
#        Grab Angle  Pinch Strength  state_type         name
# 0        0.697843        0.000000           1    Itiel Lab
# 1        2.097542        0.212742           1    Itiel Lab
# 2        0.797956        0.000000           1    Itiel Lab
# 3        1.999107        0.275051           1    Itiel Lab
# 4        0.906191        0.000000           1    Itiel Lab
# ...           ...             ...         ...          ...
# 90008    0.075099        0.000000           2  Oded Medina
# 90009    0.024162        0.000000           2  Oded Medina
# 90010    0.029208        0.000000           2  Oded Medina
# 90011    0.025365        0.000000           2  Oded Medina
# 90012    0.001149        0.000000           2  Oded Medina
#
# [90013 rows x 24 columns]
