# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
all_files = glob.glob("Training/*/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    state_type = 3
    if 'Spontan' in filename:
        state_type = 1
    elif 'Sync' in filename:
        state_type = 2
    df['state_type'] = state_type
    df['name'] = filename.split("\\")[1]
    li.append(df)

li.append(pd.read_csv("HandRight.csv",index_col=None, header=0))
df = pd.concat(li, axis=0, ignore_index=True)

# %%
# Out:
#              Time   Frame ID  Hand Type   # hands   Position X   Position Y  \
# 0        64.40649      97265       left         2   -86.519420     171.7137
# 1        64.40649      97265      right         2   143.818300     183.1156
# 2        64.42323      97266       left         2   -86.833020     170.5757
# 3        64.42323      97266      right         2   144.355000     179.8730
# 4        64.43949      97268       left         2   -87.183360     168.2926
# ...           ...        ...        ...       ...          ...          ...
# 336527  208.19420      24687      right         1   -15.404800     208.0276
# 336528  208.21080      24689      right         1   -12.678650     218.1196
# 336529  208.22760      24691      right         1    -9.643562     228.2807
# 336530  208.24430      24692      right         1    -7.980715     233.5056
# 336531  208.26190      24694      right         1    -4.468731     243.8388
#
#          Position Z   Velocity X   Velocity Y   Velocity Z  ...   Wrist Pos Y  \
# 0         -8.232538    -22.53298    -150.8182    -73.03683  ...      146.5586
# 1        -12.084150     53.41466    -405.3372     82.53658  ...      183.7971
# 2         -8.763070    -36.57425    -132.7273    -61.87682  ...      145.2127
# 3        -11.506780     62.59536    -378.1917     67.33972  ...      182.1488
# 4        -10.102310    -15.97579    -139.7671    -75.22957  ...      143.2971
# ...             ...          ...          ...          ...  ...           ...
# 336527     9.980799    167.86240     510.0852   -105.52950  ...           NaN
# 336528     9.314082    145.00970     562.3594    -20.70701  ...           NaN
# 336529     9.722980    180.42160     591.9019     28.88057  ...           NaN
# 336530    10.419080    192.45930     604.7344     80.56698  ...           NaN
# 336531    12.266750    212.20430     589.4778    133.98980  ...           NaN
#
#          Wrist Pos Z   Elbow pos X   Elbow Pos Y   Elbow Pos Z   Grab Strenth  \
# 0           3.271789     -386.4925      55.26245      16.62144            0.0
# 1          34.498820      407.6624      78.40553     123.16780            0.0
# 2           3.251141     -385.5093      51.27982      17.93486            0.0
# 3          34.862010      409.7145      82.42125     126.79130            0.0
# 4           3.186100     -382.7727      43.07076      22.46692            0.0
# ...              ...           ...           ...           ...            ...
# 336527           NaN           NaN           NaN           NaN            0.0
# 336528           NaN           NaN           NaN           NaN            0.0
# 336529           NaN           NaN           NaN           NaN            0.0
# 336530           NaN           NaN           NaN           NaN            0.0
# 336531           NaN           NaN           NaN           NaN            0.0
#
#          Grab Angle   Pinch Strength  state_type           name
# 0          0.620941              0.0         1.0  Evyatar Cohen
# 1          0.259270              0.0         1.0  Evyatar Cohen
# 2          0.637506              0.0         1.0  Evyatar Cohen
# 3          0.239628              0.0         1.0  Evyatar Cohen
# 4          0.753420              0.0         1.0  Evyatar Cohen
# ...             ...              ...         ...            ...
# 336527     0.503490              0.0         NaN            NaN
# 336528     0.403687              0.0         NaN            NaN
# 336529     0.310940              0.0         NaN            NaN
# 336530     0.286526              0.0         NaN            NaN
# 336531     0.237838              0.0         NaN            NaN
#
# [336532 rows x 24 columns]
